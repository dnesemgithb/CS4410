# %% [markdown]
# <a href="https://colab.research.google.com/github/dnesemgithb/CS4410/blob/main/9_16_Homework_Working_with_Diamonds_in_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/diamonds.csv"
df = pd.read_csv(url, index_col=0)
df
# Out:
#           carat        cut color clarity  depth  table  price     x     y  \
# rownames
# 1          0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 2          0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3          0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4          0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 5          0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...         ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53936      0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53937      0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53938      0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53939      0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53940      0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#              z
# rownames
# 1         2.43
# 2         2.31
# ...

# %%
##First 7 and last 7 rows
print("First 7 rows:\n")
display(df.head(7))

print ("Last 7 rows:")
display(df.tail(7))
# Out:
# First 7 rows:
#           carat        cut color clarity  depth  table  price     x     y  \
# rownames
# 1          0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 2          0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3          0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4          0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 5          0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 6          0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 7          0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
#
#              z
# rownames
# 1         2.43
# 2         2.31
# 3         2.31
# 4         2.63
# 5         2.75
# 6         2.48
# 7         2.47
# Last 7 rows:
#           carat        cut color clarity  depth  table  price     x     y  \
# rownames
# 53934      0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72
# ...

# %%
##DataFrame describe for carat depth table price x y and z

df.describe()
df['carat'].describe(), \
df['depth'].describe(), \
df['table'].describe(), \
df['price'].describe(), \
df['x'].describe(), \
df['y'].describe(), \
df['z'].describe()
# Out:
# (count    53940.000000
#  mean         0.797940
#  std          0.474011
#  min          0.200000
#  25%          0.400000
#  50%          0.700000
#  75%          1.040000
#  max          5.010000
#  Name: carat, dtype: float64,
#  count    53940.000000
#  mean        61.749405
#  std          1.432621
#  min         43.000000
#  25%         61.000000
#  50%         61.800000
#  75%         62.500000
#  max         79.000000
#  Name: depth, dtype: float64,
#  count    53940.000000
#  mean        57.457184
#  std          2.234491
#  min         43.000000
#  25%         56.000000
#  50%         57.000000
#  75%         59.000000
#  max         95.000000
#  Name: table, dtype: float64,
#  count    53940.000000
#  mean      3932.799722
#  std       3989.439738
#  min        326.000000
#  25%        950.000000
#  50%       2401.000000
#  75%       5324.250000
#  max      18823.000000
#  Name: price, dtype: float64,
#  count    53940.000000
#  mean         5.731157
# ...

# %%
print("Unique 'cut':", df['cut'].unique())
print("Unique 'color':", df['color'].unique())
print("Unique 'clarity':", df['clarity'].unique())
# Out:
# Unique 'cut': ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# Unique 'color': ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# Unique 'clarity': ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
# %matplotlib inline
df.hist(figsize=(10, 8))
# Out:
# array([[<Axes: title={'center': 'carat'}>,
#         <Axes: title={'center': 'depth'}>,
#         <Axes: title={'center': 'table'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: title={'center': 'x'}>,
#         <Axes: title={'center': 'y'}>],
#        [<Axes: title={'center': 'z'}>, <Axes: >, <Axes: >]], dtype=object)
